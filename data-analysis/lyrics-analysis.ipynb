# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
country_df = pd.read_csv('..\data\lyrics\Country-lyrics.csv')

# %%
country_df
# Out:
#         Unnamed: 0                        word  \
# 0                0  TranslationsFrançaisThrift
# 1                1                        Shop
# 2                2                      Lyrics
# 3                3                        Hey,
# 4                4                 Macklemore,
# ...            ...                         ...
# 568477      568477                        hold
# 568478      568478                         on,
# 568479      568479                        grr,
# 568480      568480                        grr,
# 568481      568481                   grr6Embed
#
#                                         artist         title  year  \
# 0       Macklemore & Ryan Lewis Featuring Wanz   Thrift Shop  2013
# 1       Macklemore & Ryan Lewis Featuring Wanz   Thrift Shop  2013
# 2       Macklemore & Ryan Lewis Featuring Wanz   Thrift Shop  2013
# 3       Macklemore & Ryan Lewis Featuring Wanz   Thrift Shop  2013
# ...
